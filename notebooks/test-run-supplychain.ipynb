# %% [markdown]
# # Test: Run Supplychain

# %% [markdown]
# ## Preamble

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas
import altair
from datetime import timedelta
import os

# %%
import supplyflow

# %%
supplyflow.viz.enable_theme("dark")

# %%
os.environ["LOGURU_LEVEL"] = "DEBUG"

# %% [markdown]
# ## Running Supply Chain Policies

# %%
from supplyflow.core import Product, Warehouse, DeterministicSupplyChain
from supplyflow.core import ConstantDemand, ConstantLeadTime, NormalDemand

# %%
from supplyflow.viz import supply_chain_plot

# %% [markdown]
# ### Deterministic (demand and lead time) supply chain policiesm

# %%
supply_chain = DeterministicSupplyChain(
    product=Product(
        name="Spam",
        holding_cost=1,
    ),
    warehouse=Warehouse(
        name="Warehouse 1",
    ),
    demand_source=ConstantDemand(10),
    lead_time_source=ConstantLeadTime(5),
    freq=timedelta(days=1),
    level=120,
    transaction_fixed_cost=500,
)

# %% [markdown]
# #### $(p, q)$ policy
#
# $(p,q)$ A continuous review policy with a reorder point $p$ and a fixed order quantity $q$.
#
# + Pros: low amount of safety stock needed; optimized order quantity.
# - Cons: continuous review needed; multiple items cannot be grouped in one order with one supplier.

# %%
from supplyflow.policy import PQPolicy

# %%
supply_chain.policy=PQPolicy(
    reorder_point=50, 
    quantity=100,
)

# %%
supply_chain.run(64)
# Out:
# 100%|██████████| 64/64 [00:00<00:00, 98762.13it/s]

# %%
supply_chain_plot(supply_chain).interactive()
# Out:
# /Users/cls/miniforge3/envs/supplyflow/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/cls/miniforge3/envs/supplyflow/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/cls/miniforge3/envs/supplyflow/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/cls/miniforge3/envs/supplyflow/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/cls/miniforge3/envs/supplyflow/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/cls/miniforge3/envs/supplyflow/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/cls/miniforge3/envs/supplyflow/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/cls/miniforge3/envs/supplyflow/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/cls/miniforge3/envs/supplyflow/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/cls/miniforge3/envs/supplyflow/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/cls/miniforge3/envs/supplyflow/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/cls/miniforge3/envs/supplyflow/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.VConcatChart(...)

# %% [markdown]
# - [ ] TODO: visualize out of stock and lost sales

# %% [markdown]
# ### $(r, s)$ policy
#
# $(r,s)$ A periodic review policy following a review period $r$ and an order-up-to-level $s$.
#
# + Pros: multiple items can be grouped in one order with one supplier.
# - Cons: more safety stock needed; order quantity varies and can’t be optimized.

# %%
from supplyflow.policy import RSPolicy

# %%
supply_chain.policy=RSPolicy(
    review_period=14, 
    up_to_level=150,
)

# %%
supply_chain.run(64)
# Out:
# 100%|██████████| 64/64 [00:00<00:00, 474267.59it/s]

# %%
supply_chain_plot(supply_chain).interactive()
# Out:
# /Users/cls/miniforge3/envs/supplyflow/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/cls/miniforge3/envs/supplyflow/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/cls/miniforge3/envs/supplyflow/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/cls/miniforge3/envs/supplyflow/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/cls/miniforge3/envs/supplyflow/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/cls/miniforge3/envs/supplyflow/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/cls/miniforge3/envs/supplyflow/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/cls/miniforge3/envs/supplyflow/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/cls/miniforge3/envs/supplyflow/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/cls/miniforge3/envs/supplyflow/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/cls/miniforge3/envs/supplyflow/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/cls/miniforge3/envs/supplyflow/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.VConcatChart(...)

# %% [markdown]
# ### Stochastic (demand and lead time) supply chain policies

# %%
from supplyflow.core import StochasticSupplyChain, NormalDemand, NormalLeadTime

# %%
supply_chain = StochasticSupplyChain(
    product=Product(
        name="Spam",
        holding_cost=1,
    ),
    warehouse=Warehouse(
        name="1"
    ),
    demand_source=NormalDemand(10,5),
    lead_time_source=NormalLeadTime(5,1),
    freq=timedelta(days=1),
    level=120,
    transaction_fixed_cost=500,
)

# %% [markdown]
# #### $(p, q)$ policy
#
# $(p,q)$ A continuous review policy with a reorder point $p$ and a fixed order quantity $q$.
#
# + Pros: low amount of safety stock needed; optimized order quantity.
# - Cons: continuous review needed; multiple items cannot be grouped in one order with one supplier.

# %%
supply_chain.policy=PQPolicy(
    reorder_point=75, 
    quantity=100,
)

# %%
supply_chain.run(64)
# Out:
# 100%|██████████| 64/64 [00:00<00:00, 27622.50it/s]

# %%
supply_chain_plot(supply_chain).interactive()
# Out:
# /Users/cls/miniforge3/envs/supplyflow/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/cls/miniforge3/envs/supplyflow/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/cls/miniforge3/envs/supplyflow/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/cls/miniforge3/envs/supplyflow/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/cls/miniforge3/envs/supplyflow/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/cls/miniforge3/envs/supplyflow/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/cls/miniforge3/envs/supplyflow/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/cls/miniforge3/envs/supplyflow/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/cls/miniforge3/envs/supplyflow/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/cls/miniforge3/envs/supplyflow/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/cls/miniforge3/envs/supplyflow/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/cls/miniforge3/envs/supplyflow/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.VConcatChart(...)

# %% [markdown]
# #### $(r, s)$ policy
#
# $(r,s)$ A periodic review policy following a review period $r$ and an orderup-tolevel $s$.
#
# + Pros: multiple items can be grouped in one order with one supplier.
# - Cons: more safety stock needed; order quantity varies and can’t be optimized.

# %%
supply_chain.policy=RSPolicy(
    review_period=14, 
    up_to_level=150,
)

# %%
supply_chain.run(64)
# Out:
# 100%|██████████| 64/64 [00:00<00:00, 32244.50it/s]

# %%
supply_chain_plot(supply_chain).interactive()
# Out:
# /Users/cls/miniforge3/envs/supplyflow/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/cls/miniforge3/envs/supplyflow/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/cls/miniforge3/envs/supplyflow/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/cls/miniforge3/envs/supplyflow/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/cls/miniforge3/envs/supplyflow/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/cls/miniforge3/envs/supplyflow/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/cls/miniforge3/envs/supplyflow/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/cls/miniforge3/envs/supplyflow/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/cls/miniforge3/envs/supplyflow/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/cls/miniforge3/envs/supplyflow/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/cls/miniforge3/envs/supplyflow/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/cls/miniforge3/envs/supplyflow/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.VConcatChart(...)

# %% [markdown]
# ## Metrics

# %%
supply_chain.fill_rate()
# Out:
# 0.9307324840764332

# %%
supply_chain.history_data
# Out:
#                                                  time  order  demand forecast  \
# 2025-01-22 15:24:34.377521 2025-01-22 15:24:34.974475    0.0      11     None
# 2025-01-23 15:24:34.377521 2025-01-23 15:24:34.974475    0.0       9     None
# 2025-01-24 15:24:34.377521 2025-01-24 15:24:34.974475    0.0      17     None
# 2025-01-25 15:24:34.377521 2025-01-25 15:24:34.974475    0.0       2     None
# 2025-01-26 15:24:34.377521 2025-01-26 15:24:34.974475    0.0      10     None
# ...                                               ...    ...     ...      ...
# 2025-05-25 15:24:34.377521 2025-05-25 15:24:34.974475    0.0       8     None
# 2025-05-26 15:24:34.377521 2025-05-26 15:24:34.974475    0.0       7     None
# 2025-05-27 15:24:34.377521 2025-05-27 15:24:34.974475    0.0       1     None
# 2025-05-28 15:24:34.377521 2025-05-28 15:24:34.974475   96.0       6     None
# 2025-05-29 15:24:34.377521 2025-05-29 15:24:34.974475    NaN       9     None
#
#                             level  iteration  fill_rate  avg_service_level  \
# 2025-01-22 15:24:34.377521    109          0        1.0           1.000000
# 2025-01-23 15:24:34.377521    100          1        1.0           1.000000
# 2025-01-24 15:24:34.377521     83          2        1.0           1.000000
# 2025-01-25 15:24:34.377521     81          3        1.0           1.000000
# 2025-01-26 15:24:34.377521     71          4        1.0           1.000000
# ...                           ...        ...        ...                ...
# 2025-05-25 15:24:34.377521     62        123        1.0           0.903226
# 2025-05-26 15:24:34.377521     55        124        1.0           0.904000
# 2025-05-27 15:24:34.377521     54        125        1.0           0.904762
# 2025-05-28 15:24:34.377521     48        126        1.0           0.905512
# 2025-05-29 15:24:34.377521     39        127        1.0           0.906250
#
#                             order_cycle  out_of_stock  \
# 2025-01-22 15:24:34.377521            0         False
# 2025-01-23 15:24:34.377521            0         False
# 2025-01-24 15:24:34.377521            0         False
# 2025-01-25 15:24:34.377521            0         False
# 2025-01-26 15:24:34.377521            0         False
# ...                                 ...           ...
# 2025-05-25 15:24:34.377521           11         False
# 2025-05-26 15:24:34.377521           11         False
# 2025-05-27 15:24:34.377521           11         False
# 2025-05-28 15:24:34.377521           12         False
# 2025-05-29 15:24:34.377521           12         False
#
#                             overall_avg_service_level
# 2025-01-22 15:24:34.377521                   0.963518
# 2025-01-23 15:24:34.377521                   0.963518
# 2025-01-24 15:24:34.377521                   0.963518
# 2025-01-25 15:24:34.377521                   0.963518
# 2025-01-26 15:24:34.377521                   0.963518
# ...                                               ...
# 2025-05-25 15:24:34.377521                   0.963518
# 2025-05-26 15:24:34.377521                   0.963518
# 2025-05-27 15:24:34.377521                   0.963518
# 2025-05-28 15:24:34.377521                   0.963518
# 2025-05-29 15:24:34.377521                   0.963518
#
# [128 rows x 11 columns]
